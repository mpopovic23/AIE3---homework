# %% [markdown]
# # LangSmith and Evaluation Overview with AI Makerspace
#
# Today we'll be looking at an amazing tool:
#
# [LangSmith](https://docs.smith.langchain.com/)!
#
# This tool will help us monitor, test, debug, and evaluate our LangChain applications - and more!
#
# We'll also be looking at a few Advanced Retrieval techniques along the way - and evaluate it using LangSmith!
#
# ✋BREAKOUT ROOM #1:
# - Task 1: Dependencies and OpenAI API Key
# - Task 2: Basic RAG Chain
# - Task 3: Setting Up LangSmith
# - Task 4: Examining the Trace in LangSmith!
# - Task 5: Create Testing Dataset
#
# ✋BREAKOUT ROOM #2:
# - Task 1: Parent Document Retriever
# - Task 2: Ensemble Retriever

# %% [markdown]
# ## Task 1: Dependencies and OpenAI API Key
#
# We'll be using OpenAI's suite of models today to help us generate and embed our documents for a simple RAG system built on top of LangChain's blogs!

# %%
! pip install langchain_core langchain_openai langchain_community langchain-qdrant qdrant-client langsmith openai tiktoken cohere -qU

# %%
import os
import getpass

os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter your OpenAI API Key:")

# %% [markdown]
# ## Task 2: Basic RAG Chain
#
# Now we'll set up our basic RAG chain, first up we need a model!

# %% [markdown]
# ### OpenAI Model
#
#
# We'll use OpenAI's `gpt-3.5-turbo` model to ensure we can use a stronger model for decent evaluation later!
#
# Notice that we can tag our resources - this will help us be able to keep track of which resources were used where later on!

# %%
from langchain_openai.chat_models import ChatOpenAI

base_llm = ChatOpenAI(model="gpt-3.5-turbo", tags=["base_llm"])

# %% [markdown]
# #### Asyncio Bug Handling
#
# This is necessary for Colab.

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
! pip install lxml
# Out:
# Collecting lxml
#   Downloading lxml-5.2.2-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Downloading lxml-5.2.2-cp311-cp311-manylinux_2_28_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 38.3 MB/s eta 0:00:0000:0100:01
# Installing collected packages: lxml
# Successfully installed lxml-5.2.2

# %% [markdown]
# ### SiteMap Loader
#
# We'll use a SiteMapLoader to scrape the LangChain blogs.

# %%
from langchain.document_loaders import SitemapLoader

documents = SitemapLoader(web_path="https://blog.langchain.dev/sitemap-posts.xml").load()
# Out:
# Fetching pages: 100%|##########| 221/221 [00:09<00:00, 23.99it/s]

# %%
documents[0].metadata["source"]
# Out:
# 'https://blog.langchain.dev/what-is-an-agent/'

# %% [markdown]
# ### RecursiveCharacterTextSplitter
#
# We're going to use a relatively naive text splitting strategy today!

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

split_documents = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    chunk_size = 500,
    chunk_overlap = 20
).split_documents(documents)

# %%
len(split_documents)
# Out:
# 1548

# %% [markdown]
# ### Embeddings
#
# We'll be leveraging OpenAI's [text-embedding-3-small](https://openai.com/index/new-embedding-models-and-api-updates/) today!

# %%
from langchain_openai.embeddings import OpenAIEmbeddings

base_embeddings_model = OpenAIEmbeddings(model="text-embedding-3-small")

# %% [markdown]
# ### Qdrant VectorStore Retriever
#
# Now we can use a Qdrant VectorStore to embed and store our documents and then convert it to a retriever so it can be used in our chain!

# %%
from langchain_qdrant import Qdrant

vectorstore = Qdrant.from_documents(
    split_documents,
    base_embeddings_model,
    location=":memory:",
    collection_name="langchainblogs")

# %%
base_retriever = vectorstore.as_retriever()

# %% [markdown]
# ### Prompt Template
#
# All we have left is a prompt template, which we'll create here!

# %%
from langchain.prompts import ChatPromptTemplate

base_rag_prompt_template = """\
Using the provided context, please answer the user's question. If you don't know the answer based on the context, say you don't know.

Context:
{context}

Question:
{question}
"""

base_rag_prompt = ChatPromptTemplate.from_template(base_rag_prompt_template)

# %% [markdown]
# ### LCEL Chain
#
# Now that we have:
#
# - Embeddings Model
# - Generation Model
# - Retriever
# - Prompt
#
# We're ready to build our LCEL chain!
#
# Keep in mind that we're returning our source documents with our queries - while this isn't necessary, it's a great thing to get into the habit of doing.

# %%
from operator import itemgetter
from langchain_core.runnables import RunnablePassthrough, RunnableParallel
from langchain.schema import StrOutputParser

base_rag_chain = (
    # INVOKE CHAIN WITH: {"question" : "<<SOME USER QUESTION>>"}
    # "question" : populated by getting the value of the "question" key
    # "context"  : populated by getting the value of the "question" key and chaining it into the base_retriever
    {"context": itemgetter("question") | base_retriever, "question": itemgetter("question")}
    # "context"  : is assigned to a RunnablePassthrough object (will not be called or considered in the next step)
    #              by getting the value of the "context" key from the previous step
    | RunnablePassthrough.assign(context=itemgetter("context"))
    # "response" : the "context" and "question" values are used to format our prompt object and then piped
    #              into the LLM and stored in a key called "response"
    # "context"  : populated by getting the value of the "context" key from the previous step
    | {"response": base_rag_prompt | base_llm | StrOutputParser(), "context": itemgetter("context")}
)

# %% [markdown]
# Let's test it out!

# %%
base_rag_chain.invoke({"question" : "What is a good way to evaluate agents?"})["response"]
# Out:
# 'A good way to evaluate agents is by testing their capabilities in tasks that are prerequisites for common agentic workflows, such as planning, task decomposition, function calling, and the ability to override pre-trained biases when needed. Additionally, measuring their performance across different tasks and comparing them to other models can help determine their effectiveness and reliability.'

# %% [markdown]
# ## Task 3: Setting Up LangSmith
#
# Now that we have a chain - we're ready to get started with LangSmith!
#
# We're going to go ahead and use the following `env` variables to get our Colab notebook set up to start reporting.
#
# If all you needed was simple monitoring - this is all you would need to do!

# %%
from uuid import uuid4

unique_id = uuid4().hex[0:8]

os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = f"LangSmith - {unique_id}"

# %% [markdown]
# ### LangSmith API
#
# In order to use LangSmith - you will need a beta key, you can join the queue through the `Beta Sign Up` button on LangSmith's homepage!
#
# Join [here](https://www.langchain.com/langsmith)

# %%
os.environ["LANGCHAIN_API_KEY"] = getpass.getpass('Enter your LangSmith API key: ')

# %% [markdown]
# Let's test our our first generation!

# %%
base_rag_chain.invoke({"question" : "What is LangSmith?"}, {"tags" : ["Demo Run"]})['response']
# Out:
# 'LangSmith is a unified platform for debugging, testing, evaluating, and monitoring LLM applications. It allows users to automate their feedback loop, improve collaboration, and organize workspaces. LangSmith also offers visual feedback on outputs, accuracy metrics, and real-time monitoring capabilities.'

# %% [markdown]
# ## Task 4: Examining the Trace in LangSmith!
#
# Head on over to your LangSmith web UI to check out how the trace looks in LangSmith!

# %% [markdown]
# #### 🏗️ Activity #1:
#
# Include a screenshot of your trace and explain what it means.

# %%
from IPython.display import Image

Image("Vjezba/AI_Engineering-3/Week 5/Day 2/Langsmith_trace.jpg")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/IPython/core/display.py:1045, in Image._data_and_metadata(self, always_both)
#    1044 try:
# -> 1045     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1046 except TypeError as e:
#
# TypeError: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/IPython/core/formatters.py:977, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#     974     method = get_real_method(obj, self.print_method)
#     976     if method is not None:
# --> 977         return method(include=include, exclude=exclude)
#     978     return None
#     979 else:
#
# File ~/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/IPython/core/display.py:1035, in Image._repr_mimebundle_(self, include, exclude)
#    1033 if self.embed:
#    1034     mimetype = self._mimetype
# -> 1035     data, metadata = self._data_and_metadata(always_both=True)
#    1036     if metadata:
#    1037         metadata = {mimetype: metadata}
#
# File ~/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/IPython/core/display.py:1047, in Image._data_and_metadata(self, always_both)
#    1045     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1046 except TypeError as e:
# -> 1047     raise FileNotFoundError(
#    1048         "No such file or directory: '%s'" % (self.data)) from e
#    1049 md = {}
#    1050 if self.metadata:
#
# FileNotFoundError: No such file or directory: 'Vjezba/AI_Engineering-3/Week 5/Day 2/Langsmith_trace.jpg'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/IPython/core/display.py:1045, in Image._data_and_metadata(self, always_both)
#    1044 try:
# -> 1045     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1046 except TypeError as e:
#
# TypeError: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/IPython/core/formatters.py:347, in BaseFormatter.__call__(self, obj)
#     345     method = get_real_method(obj, self.print_method)
#     346     if method is not None:
# --> 347         return method()
#     348     return None
#     349 else:
#
# File ~/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/IPython/core/display.py:1067, in Image._repr_png_(self)
#    1065 def _repr_png_(self):
#    1066     if self.embed and self.format == self._FMT_PNG:
# -> 1067         return self._data_and_metadata()
#
# File ~/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/IPython/core/display.py:1047, in Image._data_and_metadata(self, always_both)
#    1045     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1046 except TypeError as e:
# -> 1047     raise FileNotFoundError(
#    1048         "No such file or directory: '%s'" % (self.data)) from e
#    1049 md = {}
#    1050 if self.metadata:
#
# FileNotFoundError: No such file or directory: 'Vjezba/AI_Engineering-3/Week 5/Day 2/Langsmith_trace.jpg'

# %% [markdown]
# ## Task 5: Create Testing Dataset
#
# Now we can create a dataset using some user defined questions, and providing the retrieved context as a "ground truth" context.
#
# > NOTE: There are many different ways you can approach this specific task - generating ground truth answers with AI, using human experts to generate golden datasets, and more!

# %% [markdown]
# ### Synthetic Data Generation (SDG)
#
# In order to full test our RAG chain, and the various modifications we'll be using in the following notebook, we'll need to create a small synthetic dataset that is relevant to our task!
#
# Let's start by generating a series of questions - which begins with a simple model definition!
#
# > NOTE: We're going to be using a purposefully simplified datagen pipeline as an example today - but you could leverage the RAGAS SDG pipeline just as easily.

# %%
question_model = ChatOpenAI(model="gpt-4o")

# %% [markdown]
# Next up, we'll create some novel chunks from our source data!

# %%
sdg_documents = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    chunk_size = 1000,
    chunk_overlap = 20
).split_documents(documents)

# %% [markdown]
# Now, let's ask some questions that could be answered from the provided chunks!

# %%
question_prompt_template = """\
You are a University Professor creating questions for an exam. You must create a question for a given piece of context.

The question must be answerable only using the provided context.

Avoid creating questions that are ambiguous or vague. They should be specifically related to the context.

Your output must only be the question.

Context:
{context}
"""

question_prompt = ChatPromptTemplate.from_template(question_prompt_template)

# %%
question_chain = question_prompt | question_model

# %% [markdown]
# Now we can loop through a subset of our context chunks and create question/context pairs!

# %%
from tqdm import tqdm
import json

question_context_pairs = []

for idx in tqdm(range(0, len(sdg_documents), 40)):
  question = question_chain.invoke({"context" : sdg_documents[idx].page_content})
  question_context_pairs.append({"question" : question.content, "context" : sdg_documents[idx].page_content, "idx" : idx})
# Out:
# 100%|██████████| 23/23 [00:24<00:00,  1.04s/it]

# %%
question_context_pairs[0]
# Out:
# {'question': 'According to the article "What is an agent?" by Harrison Chase, published on June 28, 2024, what is the primary topic discussed?',
#  'context': 'What is an agent?\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to content\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAll Posts\n\n\n\n\nRelease Notes\n\n\n\n\nCase Studies\n\n\n\n\nIn the Loop\n\n\n\n\nLangChain\n\n\n\n\nDocs\n\n\n\n\n\nSign in\nSubscribe\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nWhat is an agent?\nIntroducing a new series of musings on AI agents.\n\nHarrison Chase\n4 min read\nJun 28, 2024',
#  'idx': 0}

# %% [markdown]
# We'll repeat this process for answers!

# %%
answer_prompt_template = """\
You are a University Professor creating an exam. You must create a answer for a given piece of context and question.

The answer must only rely on the provided context.

Your output must only be the answer.

Context:
{context}
"""

answer_prompt = ChatPromptTemplate.from_template(answer_prompt_template)

# %%
answer_chain = answer_prompt | question_model

# %%
for question_context_pair in tqdm(question_context_pairs):
  question_context_pair["answer"] = answer_chain.invoke({"question" : question_context_pair["question"], "context" : question_context_pair["context"]}).content
# Out:
# 100%|██████████| 23/23 [00:24<00:00,  1.08s/it]

# %%
question_context_pairs[0]
# Out:
# {'question': 'According to the article "What is an agent?" by Harrison Chase, published on June 28, 2024, what is the primary topic discussed?',
#  'context': 'What is an agent?\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to content\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAll Posts\n\n\n\n\nRelease Notes\n\n\n\n\nCase Studies\n\n\n\n\nIn the Loop\n\n\n\n\nLangChain\n\n\n\n\nDocs\n\n\n\n\n\nSign in\nSubscribe\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nWhat is an agent?\nIntroducing a new series of musings on AI agents.\n\nHarrison Chase\n4 min read\nJun 28, 2024',
#  'idx': 0,
#  'answer': 'An agent is an AI entity or program that performs tasks or actions on behalf of a user or other program.'}

# %% [markdown]
# Now we can set up our LangSmith client - and we'll add the above created dataset to our LangSmith instance!
#
# > NOTE: Read more about this process [here](https://docs.smith.langchain.com/old/evaluation/faq/manage-datasets#create-from-list-of-values)

# %%
from langsmith import Client

client = Client()

dataset_name = "langsmith-demo-dataset-v1"

dataset = client.create_dataset(
    dataset_name=dataset_name, description="LangChain Blog Test Questions"
)

for triplet in question_context_pairs:
  client.create_example(
      inputs={"question" : triplet["question"]},
      outputs={"answer" : triplet["answer"]},
      dataset_id=dataset.id
  )

# %% [markdown]
# ### Evaluation
#
# Now we can run the evaluation!
#
# We'll need to start by preparing some custom data preparation functions to ensure our chain works with the expected inputs/outputs from the `evaluate` process in LangSmith.
#
# > NOTE: More reading on this available [here](https://docs.smith.langchain.com/how_to_guides/evaluation/evaluate_llm_application#evaluate-a-langchain-runnable)

# %%
def prepare_data_ref(run, example):
  return {
      "prediction" : run.outputs["response"],
      "reference" : example.outputs["answer"],
      "input" : example.inputs["question"]
  }

def prepare_data_noref(run, example):
  return {
      "prediction" : run.outputs["response"],
      "input" : example.inputs["question"]
  }

# %% [markdown]
# We'll be using a few custom evaluators to evaluate our pipeline, as well as a few "built in" methods!
#
# Check out the built-ins [here](https://docs.smith.langchain.com/reference/sdk_reference/langchain_evaluators)!

# %%
from langsmith.evaluation import LangChainStringEvaluator, evaluate

cot_qa_evaluator = LangChainStringEvaluator("cot_qa", prepare_data=prepare_data_ref)

unlabeled_dopeness_evaluator = LangChainStringEvaluator(
    "criteria",
    config={
        "criteria" : {
            "dopeness" : "Is the answer to the question dope, meaning cool - awesome - and legit?"
        }
    },
    prepare_data=prepare_data_noref
)

labeled_score_evaluator = LangChainStringEvaluator(
    "labeled_score_string",
    config={
        "criteria": {
            "accuracy": "Is the generated answer the same as the reference answer?"
        },
    },
    prepare_data=prepare_data_ref
)

unlabeled_coherence_evaluator = LangChainStringEvaluator("criteria", config={"criteria": "coherence"}, prepare_data=prepare_data_noref)
labeled_relevance_evaluator = LangChainStringEvaluator("labeled_criteria", config={ "criteria": "relevance"}, prepare_data=prepare_data_ref)

base_rag_results = evaluate(
    base_rag_chain.invoke,
    data=dataset_name,
    evaluators=[
        cot_qa_evaluator,
        unlabeled_dopeness_evaluator,
        labeled_score_evaluator,
        unlabeled_coherence_evaluator,
        labeled_relevance_evaluator
        ],
    experiment_prefix="Base RAG Evaluation"
)
# Out:
# View the evaluation results for experiment: 'Base RAG Evaluation-0224642b' at:
# https://smith.langchain.com/o/fc1b336b-59a7-5844-8ab1-ad626257e5b9/datasets/984aa208-5d9a-4325-b715-5ff8fcb4f3dc/compare?selectedSessions=4d8f824b-45b7-447f-9d92-18a089ddc936
# 0it [00:00, ?it/s]
# Error running evaluator <DynamicRunEvaluator evaluate> on run 8427f50c-dcf8-4697-b491-61cfa5edcf1c: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9745, Requested 256. Please try again in 6ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/scoring/eval_chain.py", line 352, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9745, Requested 256. Please try again in 6ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run a72503d5-c3c3-46e3-aba2-55b6e8160f1d: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9883, Requested 330. Please try again in 1.278s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/scoring/eval_chain.py", line 352, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9883, Requested 330. Please try again in 1.278s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run c056fd5c-39f0-465c-b494-83acd53ad11c: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9972, Requested 238. Please try again in 1.26s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9972, Requested 238. Please try again in 1.26s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 4d2ad999-9c87-45dc-89bd-a5fe6b874c55: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9949, Requested 261. Please try again in 1.26s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9949, Requested 261. Please try again in 1.26s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 0677cf43-635d-420c-92c8-d8a646419cd5: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9954, Requested 254. Please try again in 1.248s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9954, Requested 254. Please try again in 1.248s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 0f469495-2c4a-44c2-bff3-b2050db2908c: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9922, Requested 280. Please try again in 1.212s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9922, Requested 280. Please try again in 1.212s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 83232756-f365-4504-8cd5-5cefc7b313ad: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9900, Requested 311. Please try again in 1.266s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9900, Requested 311. Please try again in 1.266s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run ac7e633b-0e0f-4f14-9022-ca1c4a972dab: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9731, Requested 287. Please try again in 108ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
# ...
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9854, Requested 404. Please try again in 1.548s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 0a7b4171-8f3a-4e5b-ac33-3bd4ea8e8ad6: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9861, Requested 393. Please try again in 1.524s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9861, Requested 393. Please try again in 1.524s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 69dd39ae-2177-4355-a57f-c4528627ed8d: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9843, Requested 406. Please try again in 1.494s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9843, Requested 406. Please try again in 1.494s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}

# %% [markdown]
# ## Testing Other Retrievers
#
# Now we can test our how changing our Retriever impacts our LangSmith evaluation!
#
# We'll build this simple qa_chain factory to create standardized qa_chains where the only different component will be the retriever.

# %%
def create_qa_chain(retriever):
  primary_qa_llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)
  created_qa_chain = (
    {"context": itemgetter("question") | retriever,
     "question": itemgetter("question")
    }
    | RunnablePassthrough.assign(
        context=itemgetter("context")
      )
    | {
         "response": base_rag_prompt | primary_qa_llm,
         "context": itemgetter("context"),
      }
  )
  return created_qa_chain

# %% [markdown]
# ### Task 1: Parent Document Retriever
#
# One of the easier ways we can imagine improving a retriever is to embed our documents into small chunks, and then retrieve a significant amount of additional context that "surrounds" the found context.
#
# You can read more about this method [here](https://python.langchain.com/docs/modules/data_connection/retrievers/parent_document_retriever)!
#
# The basic outline of this retrieval method is as follows:
#
# 1. Obtain User Question
# 2. Retrieve child documents using Dense Vector Retrieval
# 3. Merge the child documents based on their parents. If they have the same parents - they become merged.
# 4. Replace the child documents with their respective parent documents from an in-memory-store.
# 5. Use the parent documents to augment generation.

# %%
from langchain.retrievers import ParentDocumentRetriever
from langchain.storage import InMemoryStore
from qdrant_client import QdrantClient
from qdrant_client.models import Distance, VectorParams

client = QdrantClient(":memory:")
client.create_collection(
    collection_name="split_parents",
    vectors_config=VectorParams(size=1536, distance=Distance.COSINE),
)

vectorstore = Qdrant(client, collection_name="split_parents", embeddings=base_embeddings_model)

store = InMemoryStore()

# %%
parent_document_retriever = ParentDocumentRetriever(
    vectorstore=vectorstore,
    docstore=store,
    child_splitter=RecursiveCharacterTextSplitter(chunk_size=400),
    parent_splitter=RecursiveCharacterTextSplitter(chunk_size=2000),
)

# %%
parent_document_retriever.add_documents(documents)

# %% [markdown]
# Let's create, test, and then evaluate our new chain!

# %%
parent_document_retriever_qa_chain = create_qa_chain(parent_document_retriever)

# %%
parent_document_retriever_qa_chain.invoke({"question" : "What is RAG?"})["response"].content
# Out:
# 'RAG stands for Retrieval Augmented Generation, which is a central paradigm in Large Language Model (LLM) application development. It involves connecting LLMs to external data sources to improve the quality of generated answers by grounding them in retrieved context.'

# %% [markdown]
# #### Evaluating the Parent Document Retrieval Pipeline
#
# Now that we've created a new retriever - let's try evaluating it on the same dataset!

# %%
pdr_rag_results = evaluate(
    parent_document_retriever_qa_chain.invoke,
    data=dataset_name,
    evaluators=[
        cot_qa_evaluator,
        unlabeled_dopeness_evaluator,
        labeled_score_evaluator,
        unlabeled_coherence_evaluator,
        labeled_relevance_evaluator
        ],
    experiment_prefix="Parent Document Retrieval RAG Evaluation"
)
# Out:
# View the evaluation results for experiment: 'Parent Document Retrieval RAG Evaluation-f05ffc8a' at:
# https://smith.langchain.com/o/fc1b336b-59a7-5844-8ab1-ad626257e5b9/datasets/984aa208-5d9a-4325-b715-5ff8fcb4f3dc/compare?selectedSessions=a4a43c2e-7a68-48d6-8077-1a0664f39d0e
# 0it [00:00, ?it/s]
# Error running evaluator <DynamicRunEvaluator evaluate> on run ab274fda-3435-4e27-b2f9-e08b1459e8b2: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9700, Requested 319. Please try again in 114ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/scoring/eval_chain.py", line 352, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9700, Requested 319. Please try again in 114ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 6d9270f6-22e0-44cc-afbe-20c8637b9e43: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9689, Requested 334. Please try again in 138ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/scoring/eval_chain.py", line 352, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9689, Requested 334. Please try again in 138ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 7fcf3ec6-111a-42d6-8beb-f2749e5b5ef3: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9935, Requested 347. Please try again in 1.692s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9935, Requested 347. Please try again in 1.692s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run def76930-96c3-4836-b571-b62f12616eaf: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9939, Requested 349. Please try again in 1.728s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/scoring/eval_chain.py", line 352, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9939, Requested 349. Please try again in 1.728s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 5ebb8468-3337-448c-add4-6db93ba80e68: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9927, Requested 413. Please try again in 2.04s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/scoring/eval_chain.py", line 352, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9927, Requested 413. Please try again in 2.04s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 0dd25cae-d607-4f37-91a8-974d07c644cc: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9882, Requested 405. Please try again in 1.722s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/scoring/eval_chain.py", line 352, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9882, Requested 405. Please try again in 1.722s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 2859555a-57d2-41c3-bac4-9e2be4c2bd74: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9882, Requested 408. Please try again in 1.74s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/scoring/eval_chain.py", line 352, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9882, Requested 408. Please try again in 1.74s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run a5da48e9-c16d-4600-8826-ca4a9952dbbb: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9846, Requested 442. Please try again in 1.728s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
# ...
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9906, Requested 524. Please try again in 2.58s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run abc0cb93-bfd8-4b36-86b6-161fbfb7df5a: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9872, Requested 563. Please try again in 2.61s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9872, Requested 563. Please try again in 2.61s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 77e0c7b4-903e-4d49-a94b-246fb4fd000d: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9699, Requested 539. Please try again in 1.428s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9699, Requested 539. Please try again in 1.428s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}

# %% [markdown]
# ### Task 2: Ensemble Retrieval
#
# Next let's look at ensemble retrieval!
#
# You can read more about this [here](https://python.langchain.com/docs/modules/data_connection/retrievers/ensemble)!
#
# The basic idea is as follows:
#
# 1. Obtain User Question
# 2. Hit the Retriever Pair
#     - Retrieve Documents with BM25 Sparse Vector Retrieval
#     - Retrieve Documents with Dense Vector Retrieval Method
# 3. Collect and "fuse" the retrieved docs based on their weighting using the [Reciprocal Rank Fusion](https://plg.uwaterloo.ca/~gvcormac/cormacksigir09-rrf.pdf) algorithm into a single ranked list.
# 4. Use those documents to augment our generation.
#
# Ensure your `weights` list - the relative weighting of each retriever - sums to 1!

# %%
! pip install -q -U rank_bm25

# %%
from langchain.retrievers import BM25Retriever, EnsembleRetriever

text_splitter = RecursiveCharacterTextSplitter(chunk_size=450, chunk_overlap=75)
split_documents = text_splitter.split_documents(documents)

bm25_retriever = BM25Retriever.from_documents(split_documents)
bm25_retriever.k = 2

embedding = OpenAIEmbeddings()
vectorstore = Qdrant.from_documents(split_documents, embedding, location=":memory:")
qdrant_retriever = vectorstore.as_retriever(search_kwargs={"k": 3})

ensemble_retriever = EnsembleRetriever(
    retrievers=[
        bm25_retriever,
        qdrant_retriever
    ],
    weights=[
        0.5,
        0.5
    ])

# %%
ensemble_retriever_qa_chain = create_qa_chain(ensemble_retriever)

# %%
ensemble_retriever_qa_chain.invoke({"question" : "What is RAG?"})["response"].content
# Out:
# 'RAG stands for Retrieval Augmented Generation, which is a central paradigm in LLM (Large Language Models) application development. It involves connecting LLMs to external data sources to address the lack of recent information and private data that may be inaccessible for training.'

# %%
pdr_rag_results = evaluate(
    ensemble_retriever_qa_chain.invoke,
    data=dataset_name,
    evaluators=[
        cot_qa_evaluator,
        unlabeled_dopeness_evaluator,
        labeled_score_evaluator,
        unlabeled_coherence_evaluator,
        labeled_relevance_evaluator
        ],
    experiment_prefix="Hybrid Retrieval RAG Evaluation"
)
# Out:
# View the evaluation results for experiment: 'Hybrid Retrieval RAG Evaluation-92bcd198' at:
# https://smith.langchain.com/o/fc1b336b-59a7-5844-8ab1-ad626257e5b9/datasets/984aa208-5d9a-4325-b715-5ff8fcb4f3dc/compare?selectedSessions=0627d9ab-9080-49fb-999b-f92e78b814ab
# 0it [00:00, ?it/s]
# Error running evaluator <DynamicRunEvaluator evaluate> on run 35a587fc-48f2-4743-9f13-4d2837fb0091: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9691, Requested 332. Please try again in 138ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/scoring/eval_chain.py", line 352, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9691, Requested 332. Please try again in 138ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run d0651f43-ba75-4791-ae02-881c0eba95ea: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9681, Requested 343. Please try again in 144ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/scoring/eval_chain.py", line 352, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9681, Requested 343. Please try again in 144ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 830a04b6-c470-42f1-9c8a-2fb911e6721e: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9676, Requested 348. Please try again in 144ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/scoring/eval_chain.py", line 352, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9676, Requested 348. Please try again in 144ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run b0c038a9-2226-4b27-b638-b765b78e5afa: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9877, Requested 318. Please try again in 1.17s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/scoring/eval_chain.py", line 352, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9877, Requested 318. Please try again in 1.17s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 76a8d870-bab4-452d-b268-31626254ec05: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9861, Requested 387. Please try again in 1.488s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/scoring/eval_chain.py", line 352, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9861, Requested 387. Please try again in 1.488s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run ffef2f2b-c6f7-4c45-805a-e748ee979383: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9844, Requested 404. Please try again in 1.488s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/scoring/eval_chain.py", line 352, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9844, Requested 404. Please try again in 1.488s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 55902408-710a-40f3-843b-df71f286c076: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9766, Requested 430. Please try again in 1.176s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/scoring/eval_chain.py", line 352, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9766, Requested 430. Please try again in 1.176s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run a79e7778-124f-439e-a951-bfbe31f3d5d3: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9672, Requested 522. Please try again in 1.164s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
# ...
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9604, Requested 483. Please try again in 522ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 72261117-112f-4396-b637-9814ae5a662a: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9642, Requested 444. Please try again in 516ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9642, Requested 444. Please try again in 516ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Error running evaluator <DynamicRunEvaluator evaluate> on run 323f7355-950d-4716-b776-80b073e97e4d: RateLimitError("Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9564, Requested 538. Please try again in 612ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}")
# Traceback (most recent call last):
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/_runner.py", line 1233, in _run_evaluators
#     evaluator_response = evaluator.evaluate_run(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/evaluator.py", line 278, in evaluate_run
#     result = self.func(
#              ^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 568, in wrapper
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/run_helpers.py", line 565, in wrapper
#     function_result = run_container["context"].run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langsmith/evaluation/integrations/_langchain.py", line 257, in evaluate
#     results = self.evaluator.evaluate_strings(**eval_inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/schema.py", line 219, in evaluate_strings
#     return self._evaluate_strings(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/evaluation/criteria/eval_chain.py", line 447, in _evaluate_strings
#     result = self(
#              ^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/_api/deprecation.py", line 168, in warning_emitting_wrapper
#     return wrapped(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 383, in __call__
#     return self.invoke(
#            ^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 166, in invoke
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/base.py", line 156, in invoke
#     self._call(inputs, run_manager=run_manager)
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 127, in _call
#     response = self.generate([inputs], run_manager=run_manager)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain/chains/llm.py", line 139, in generate
#     return self.llm.generate_prompt(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 677, in generate_prompt
#     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 534, in generate
#     raise e
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 524, in generate
#     self._generate_with_cache(
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py", line 749, in _generate_with_cache
#     result = self._generate(
#              ^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/langchain_openai/chat_models/base.py", line 549, in _generate
#     response = self.client.create(messages=message_dicts, **params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_utils/_utils.py", line 277, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/resources/chat/completions.py", line 643, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1250, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 931, in request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1015, in _request
#     return self._retry_request(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1063, in _retry_request
#     return self._request(
#            ^^^^^^^^^^^^^^
#   File "/home/mpopovic1/anaconda3/envs/llmops-course2/lib/python3.11/site-packages/openai/_base_client.py", line 1030, in _request
#     raise self._make_status_error_from_response(err.response) from None
# openai.RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4 in organization org-UJkfUQG4yAuCA8AVBA1151ha on tokens per min (TPM): Limit 10000, Used 9564, Requested 538. Please try again in 612ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}

# %% [markdown]
# #### ❓Question #1:
#
# What conclusions can you draw about the above results?
#
# Describe in your own words what the metrics are expressing.
